# %%
import json
from pathlib import Path

# Check documents
doc_path = Path('../data/processed/movie_documents.json')
if doc_path.exists():
    with open(doc_path) as f:
        docs = json.load(f)
    print(f"✅ Found {len(docs)} documents")
    print(f"✅ Minimum requirement met: {len(docs) >= 10}")
else:
    print("❌ Documents not found")

# Check markdown files
md_dir = Path('../data/processed/markdown_docs')
if md_dir.exists():
    md_files = list(md_dir.glob('*.md'))
    print(f"✅ Found {len(md_files)} markdown files")
else:
    print("❌ Markdown files not found")
# Out:
# ✅ Found 17 documents
# ✅ Minimum requirement met: True
# ✅ Found 16 markdown files
